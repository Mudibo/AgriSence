# %% [markdown]
# # 03 - Climate Ablation
#
# This notebook measures the impact of climate variables on crop price forecasting by comparing the model with and without climatic features.

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

project_root = Path.cwd().resolve().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from config.constants import CROPS, MARKETS

# %% [markdown]
# ## Train with climate features

# %% [markdown]
# ## Train without climate features

# %% [markdown]
# ## Compare validation performance

# %% [markdown]
# ## Decision
