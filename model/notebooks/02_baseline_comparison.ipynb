# %% [markdown]
# # 02 - Baseline Comparison
#
# This notebook compares the linear regression and SARIMA baselines using the same feature set and shared validation logic.

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

project_root = Path.cwd().resolve().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from config.constants import CROPS, MARKETS

# %% [markdown]
# ## Load features

# %% [markdown]
# ## Train Linear Regression

# %% [markdown]
# ## Train XGBoost

# %% [markdown]
# ## Train RandomForest

# %% [markdown]
# ## Compare MAE/RMSE/MAPE
