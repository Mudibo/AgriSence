# %% [markdown]
# # 01 - EDA
#
# This notebook performs a comprehensive exploratory data analysis on the pricing dataset used to train the machine learning models in the project

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

try:
    import google.colab  # noqa: F401
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

REPO_URL = "https://github.com/Mudibo/AgriSence.git" 

if IN_COLAB:
    REPO_DIR = Path("/content/AgriSence")
    if not REPO_DIR.exists():
        # !git clone {REPO_URL} {REPO_DIR}
    project_root = REPO_DIR / "model"
else:
    project_root = Path.cwd().resolve().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# Local imports for project modules
from config.constants import CROPS, MARKETS

sns.set_theme(style="whitegrid")

# %% [markdown]
# <h3>1. Data Loading</h3>

# %%
WFP_URL = (
    "https://data.humdata.org/dataset/wfp-food-prices-for-kenya/resource/"
    "517ee1bf-2437-4f8c-aa1b-cb9925b9d437/download/wfp_food_prices_ken.csv"
)

raw_df = pd.read_csv(WFP_URL)

# HDX exports ship a units/type row directly under the header
if raw_df.iloc[0].astype(str).str.match(r"^#").any():
    raw_df = raw_df.iloc[1:].reset_index(drop=True)

print(raw_df.shape)
# Out:
# (27774, 16)

# %% [markdown]
# <h3> 2. Dataset Inspection</h3>

# %%
raw_df.shape
# Out:
# (27774, 16)

# %%
raw_df.tail()
# Out:
#              date       admin1   admin2              market  market_id  \
# 27769  2026-08-15  Rift Valley  Turkana  Mogadishu (Kakuma)       3245
# 27770  2026-08-15  Rift Valley  Turkana  Mogadishu (Kakuma)       3245
# 27771  2026-08-15  Rift Valley  Turkana  Mogadishu (Kakuma)       3245
# 27772  2026-08-15  Rift Valley  Turkana  Mogadishu (Kakuma)       3245
# 27773  2026-08-15  Rift Valley  Turkana  Mogadishu (Kakuma)       3245
#
#        latitude  longitude               category        commodity  \
# 27769      3.72      34.85         milk and dairy       Milk (UHT)
# 27770      3.72      34.85     miscellaneous food             Salt
# 27771      3.72      34.85     miscellaneous food            Sugar
# 27772      3.72      34.85           oil and fats  Oil (vegetable)
# 27773      3.72      34.85  vegetables and fruits          Bananas
#
#        commodity_id    unit  priceflag pricetype currency   price  usdprice
# 27769           794  500 ML  aggregate    Retail      KES   75.00      0.58
# 27770           185   200 G  aggregate    Retail      KES   15.00      0.12
# 27771            97      KG  aggregate    Retail      KES  163.33      1.26
# 27772            96       L  aggregate    Retail      KES  300.00      2.32
# 27773           254    Unit  aggregate    Retail      KES   20.00      0.15

# %%
raw_df.head()
# Out:
#          date   admin1   admin2   market  market_id  latitude  longitude  \
# 0  2006-01-15    Coast  Mombasa  Mombasa        191     -4.05      39.67
# 1  2006-01-15    Coast  Mombasa  Mombasa        191     -4.05      39.67
# 2  2006-01-15    Coast  Mombasa  Mombasa        191     -4.05      39.67
# 3  2006-01-15  Eastern    Kitui    Kitui        187     -1.37      38.02
# 4  2006-01-15  Eastern    Kitui    Kitui        187     -1.37      38.02
#
#              category         commodity  commodity_id   unit priceflag  \
# 0  cereals and tubers     Maize (white)            67  90 KG    actual
# 1     pulses and nuts             Beans            50     KG    actual
# 2     pulses and nuts       Beans (dry)           262  90 KG    actual
# 3  cereals and tubers     Maize (white)            67     KG    actual
# 4  cereals and tubers  Potatoes (Irish)           148  50 KG    actual
#
#    pricetype currency    price  usdprice
# 0  Wholesale      KES  1480.00     20.58
# 1  Wholesale      KES    33.63      0.47
# 2  Wholesale      KES  3246.00     45.15
# 3     Retail      KES    17.00      0.24
# 4  Wholesale      KES  1249.99     17.39

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27774 entries, 0 to 27773
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          27774 non-null  object
#  1   admin1        27706 non-null  object
#  2   admin2        27706 non-null  object
#  3   market        27774 non-null  object
#  4   market_id     27774 non-null  int64
#  5   latitude      27706 non-null  float64
#  6   longitude     27706 non-null  float64
#  7   category      27774 non-null  object
#  8   commodity     27774 non-null  object
#  9   commodity_id  27774 non-null  int64
#  10  unit          27774 non-null  object
#  11  priceflag     27774 non-null  object
#  12  pricetype     27774 non-null  object
#  13  currency      27774 non-null  object
#  14  price         27774 non-null  float64
#  15  usdprice      27774 non-null  float64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 3.4+ MB

# %%
raw_df.dtypes
# Out:
# date             object
# admin1           object
# admin2           object
# market           object
# market_id         int64
# latitude        float64
# longitude       float64
# category         object
# commodity        object
# commodity_id      int64
# unit             object
# priceflag        object
# pricetype        object
# currency         object
# price           float64
# usdprice        float64
# dtype: object

# %%
raw_df["market"].nunique()
# Out:
# 226

# %%
raw_df["market"].unique()
# Out:
# array(['Mombasa', 'Kitui', 'Marsabit', 'Nairobi', 'Mandera', 'Kisumu',
#        'Lodwar (Turkana)', 'Eldoret town (Uasin Gishu)', 'Nakuru',
#        'Hola (Tana River)', 'Kilifi', 'Garissa', 'Marigat (Baringo)',
#        'Kajiado', 'Karatina (Nyeri)', 'Vanga (Kwale)',
#        'Kitui town (Kitui)', 'Makueni', 'Wote town (Makueni)',
#        'Kitengela (Kajiado)', 'Garissa town (Garissa)',
#        'Takaba (Mandera)', 'Marigat town (Baringo)',
#        'Illbissil Food Market (Kajiado)', 'Wakulima (Nakuru)',
#        'Lomut (West Pokot)', 'Kongowea (Mombasa)',
#        'Tala Centre Market (Machakos)', 'Kangemi (Nairobi)',
#        'Kibuye (Kisumu)', 'Makutano (West Pokot)',
#        'Kathonzweni (Makueni)', 'Kaanwa (Tharaka Nithi)',
#        'Wakulima (Nairobi)', 'Shauri Yako', 'Bangale', 'Boka', 'Bura',
#        'Charidende', 'Garsen', 'Hola town', 'Makere', 'Saka Town',
#        'Tarasaa', 'Wayu', 'Benane', 'Biliqo', 'Boji', 'Bulesa Bulesa',
#        'Garbatulla', 'Iresaboru Centre', 'Kipsing CENTER', 'Malka GALLA',
#        'Malkadaka', 'Merti CENTER', 'Modogashe', 'Oldonyiro',
#        'Sericho Center', 'Dirib', 'Dub Goba', 'Karare', 'Kargi',
#        'Kargi South Horr', 'Korr', 'Laisamis Town', 'Loglogo',
#        'Loyangalani', 'Merille Town', 'Songa', 'Ngaremara',
#        'Dagahaley (Daadab)', 'Dertu', 'Hagadera (Daadab)', 'IFO (Daadab)',
#        'Maalamin', 'Shanta Abak', 'Ashabito', 'Kiliwaheri',
#        'Mandera town', 'Rhamu', 'Bute', 'Eldas', 'Griftu', 'Tarbaj',
#        'Chemolingot', 'Loboi Center', 'Nginyang', 'Baragoi', 'Kisima',
#        'Lengusaka', 'Lesirkan', 'Lodungokwe', 'Lolkuniyani', 'Lolkunono',
#        'Loosuk', 'Lpus', 'Maralal', 'Ngilai', 'Ngurunit', 'Porro',
#        'Suguta', 'Wamba', 'Alemsekon', 'Aposta', 'Elelea', 'Kaakelai',
#        'Kaeris', 'Kakuma 4', 'Kalemgorok', 'Kalemunyang', 'Kaleng',
#        'Kalobeyei (Village 1)', 'Kalobeyei (Village 2)',
#        'Kalobeyei (Village 3)', 'Kalokol', 'Kataboi', 'Katilia', 'Kokuro',
#        'Letea', 'Lokichar (Turkana)', 'Lokichoggio', 'Lokiriama',
#        'Lokitaung', 'Lokori', 'Lolupe', 'Lopur', 'Lorugum', 'Loturerei',
#        'Lowarengak', 'Naakalei', 'Naduat', 'Nakinomet', 'Nakukulas',
#        'Namoruputh', 'Napak', 'Turkwel Centre', 'Urum', 'Mtito Andei',
#        'Bilbil', 'Kipini', 'Emali', 'Kibwezi', 'Kiwanja', 'Alango Arba',
#        'Alinjugur', 'Baraki', 'Dadaab town', 'Damajale', 'Jarajara',
#        'Liboi', 'Nanigi', 'Saretho', 'Banissa', 'El Wak', 'Habaswein',
#        'Hadado', 'Lagbogol', 'Amaya', 'Kimalel Center', 'Koriema',
#        'Lororo Centre', 'Eliye Centre', 'HongKong (Kakuma)', 'Kaikor',
#        'Kakuma 2', 'Kakuma 3', 'Lokangae', 'Lokapel', 'Lokwii', 'Lotubae',
#        'Mogadishu (Kakuma)', 'Morulem', 'Adele Center', 'Masalani',
#        'Minjila', 'Waldena', 'Isiolo town', 'Kinna', 'Kulamawe',
#        'Maikona', 'North Horr', 'Dambala Fachana', 'Moyale town', 'Walda',
#        'Mathaxgesi', 'Hara (Garissa)', 'Kotile', 'Alungu', 'Warankara',
#        'Buna', 'Archers Post', 'Masikita', 'Nachola', 'Simale',
#        'Ethiopia (Kakuma)', 'Kakuma town', 'Kalobeyei town',
#        "Kang'akipur", 'Kasuroi', 'Kibish', 'Lodwar town', 'Lorengipi',
#        'Todonyang', 'Dzikunze', 'Kachororoni', 'Kaembeni', 'Sololo',
#        'Korakora', 'Suq Jini', 'Tuum', 'Lokipoto', 'Matanomanne',
#        'Wargadud', 'Bangladesh (Mombasa)', 'Kalahari (Mombasa)',
#        'Shonda (Mombasa)', 'Kawangware (Nairobi)', 'Kibra (Nairobi)',
#        'Mathare (Nairobi)', 'Mukuru (Nairobi)', 'Dandora (Nairobi)',
#        'Wajir town', 'Junda (Mombasa)', 'Moroto (Mombasa)',
#        'Kisumu Ndogo (Mombasa)', 'Marsabit town'], dtype=object)

# %%
raw_df["commodity"].nunique()
# Out:
# 51

# %%
raw_df["commodity"].unique()
# Out:
# array(['Maize (white)', 'Beans', 'Beans (dry)', 'Potatoes (Irish)',
#        'Sorghum', 'Bread', 'Maize', 'Milk (cow, pasteurized)',
#        'Oil (vegetable)', 'Fuel (diesel)', 'Fuel (kerosene)',
#        'Fuel (petrol-gasoline)', 'Maize flour', 'Rice', 'Wheat flour',
#        'Meat (beef)', 'Meat (goat)', 'Sugar', 'Cooking fat', 'Bananas',
#        'Kale', 'Onions (red)', 'Tomatoes', 'Potatoes (Irish, red)',
#        'Beans (kidney)', 'Beans (rosecoco)', 'Beans (yellow)', 'Cabbage',
#        'Onions (dry)', 'Spinach', 'Potatoes (Irish, white)',
#        'Rice (aromatic)', 'Sorghum (red)', 'Beans (dolichos)', 'Cowpeas',
#        'Cowpea leaves', 'Maize (white, dry)', 'Beans (mung)',
#        'Millet (finger)', 'Rice (imported, Pakistan)',
#        'Fish (omena, dry)', 'Sorghum (white)', 'Maize flour (white)',
#        'Salt', 'Oil (vegetable, fortified)', 'Cowpeas (dry)',
#        'Pigeon peas (dry)', 'Milk (UHT)', 'Meat (camel)',
#        'Milk (camel, fresh)', 'Milk (cow, fresh)'], dtype=object)

# %%
raw_df["unit"].nunique()
# Out:
# 13

# %%
raw_df["unit"].unique()
# Out:
# array(['90 KG', 'KG', '50 KG', '400 G', '500 ML', 'L', 'Unit', 'Bunch',
#        '126 KG', '13 KG', '64 KG', '200 G', 'Head'], dtype=object)

# %%
raw_df["currency"].nunique()
# Out:
# 1

# %%
raw_df["currency"].unique()
# Out:
# array(['KES'], dtype=object)

# %% [markdown]
# <h3>3. Data Quality Checks</h3>

# %%
#Missing values check
missing = raw_df.isnull().sum().sort_values(ascending=False)
missing
# Out:
# admin1          68
# admin2          68
# longitude       68
# latitude        68
# market           0
# date             0
# market_id        0
# category         0
# commodity        0
# commodity_id     0
# unit             0
# priceflag        0
# pricetype        0
# currency         0
# price            0
# usdprice         0
# dtype: int64

# %%
# Percentage Calculation
missing_percentage = (raw_df.isnull().sum() / len(raw_df) * 100).sort_values(ascending=False)
missing_percentage
# Out:
# admin1          0.244833
# admin2          0.244833
# longitude       0.244833
# latitude        0.244833
# market          0.000000
# date            0.000000
# market_id       0.000000
# category        0.000000
# commodity       0.000000
# commodity_id    0.000000
# unit            0.000000
# priceflag       0.000000
# pricetype       0.000000
# currency        0.000000
# price           0.000000
# usdprice        0.000000
# dtype: float64

# %%
# Investigating missingness by market
raw_df.groupby("market")["price"].apply(lambda x: x.isna().mean())
# Out:
# market
# Adele Center           0.0
# Alango Arba            0.0
# Alemsekon              0.0
# Alinjugur              0.0
# Alungu                 0.0
#                       ...
# Wamba                  0.0
# Warankara              0.0
# Wargadud               0.0
# Wayu                   0.0
# Wote town (Makueni)    0.0
# Name: price, Length: 226, dtype: float64

# %%
raw_df.groupby("commodity")["price"].apply(lambda x: x.isna().mean())
# Out:
# commodity
# Bananas                       0.0
# Beans                         0.0
# Beans (dolichos)              0.0
# Beans (dry)                   0.0
# Beans (kidney)                0.0
# Beans (mung)                  0.0
# Beans (rosecoco)              0.0
# Beans (yellow)                0.0
# Bread                         0.0
# Cabbage                       0.0
# Cooking fat                   0.0
# Cowpea leaves                 0.0
# Cowpeas                       0.0
# Cowpeas (dry)                 0.0
# Fish (omena, dry)             0.0
# Fuel (diesel)                 0.0
# Fuel (kerosene)               0.0
# Fuel (petrol-gasoline)        0.0
# Kale                          0.0
# Maize                         0.0
# Maize (white)                 0.0
# Maize (white, dry)            0.0
# Maize flour                   0.0
# Maize flour (white)           0.0
# Meat (beef)                   0.0
# Meat (camel)                  0.0
# Meat (goat)                   0.0
# Milk (UHT)                    0.0
# Milk (camel, fresh)           0.0
# Milk (cow, fresh)             0.0
# Milk (cow, pasteurized)       0.0
# Millet (finger)               0.0
# Oil (vegetable)               0.0
# Oil (vegetable, fortified)    0.0
# Onions (dry)                  0.0
# Onions (red)                  0.0
# Pigeon peas (dry)             0.0
# Potatoes (Irish)              0.0
# Potatoes (Irish, red)         0.0
# Potatoes (Irish, white)       0.0
# Rice                          0.0
# Rice (aromatic)               0.0
# Rice (imported, Pakistan)     0.0
# Salt                          0.0
# Sorghum                       0.0
# Sorghum (red)                 0.0
# Sorghum (white)               0.0
# Spinach                       0.0
# Sugar                         0.0
# Tomatoes                      0.0
# Wheat flour                   0.0
# Name: price, dtype: float64

# %% [markdown]
# <h3>4. Duplicate Observations</h3>

# %%
raw_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = raw_df.copy()

# %% [markdown]
# <h3>5. Date and temporal Coverage</h3>

# %%
#Converting date field to datetime format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df['date'].min()
# Out:
# Timestamp('2006-01-15 00:00:00')

# %%
df['date'].max()
# Out:
# Timestamp('2026-08-15 00:00:00')

# %% [markdown]
# <h3>6. Market Coverage</h3>

# %%
df['market'].value_counts().head(20)
# Out:
# market
# Nairobi                       1762
# Eldoret town (Uasin Gishu)    1392
# Kisumu                         962
# IFO (Daadab)                   812
# Kakuma 3                       790
# Hagadera (Daadab)              768
# Kakuma 4                       701
# Dagahaley (Daadab)             681
# Kalobeyei (Village 1)          680
# Kakuma 2                       672
# Kitui                          649
# Kalobeyei (Village 2)          622
# Mombasa                        616
# HongKong (Kakuma)              612
# Ethiopia (Kakuma)              608
# Kalobeyei (Village 3)          588
# Mogadishu (Kakuma)             586
# Kangemi (Nairobi)              576
# Nakuru                         541
# Garissa town (Garissa)         468
# Name: count, dtype: int64

# %%
df[df['market'] == 'Kisumu'].sort_values(by='date').tail()
# Out:
#            date  admin1  admin2  market  market_id  latitude  longitude  \
# 6121 2019-10-15  Nyanza  Kisumu  Kisumu        186      -0.1      34.75
# 6122 2019-10-15  Nyanza  Kisumu  Kisumu        186      -0.1      34.75
# 6266 2020-02-15  Nyanza  Kisumu  Kisumu        186      -0.1      34.75
# 6303 2020-03-15  Nyanza  Kisumu  Kisumu        186      -0.1      34.75
# 8751 2022-02-15  Nyanza  Kisumu  Kisumu        186      -0.1      34.75
#
#                 category    commodity  commodity_id   unit priceflag  \
# 6121  cereals and tubers      Sorghum            65  90 KG    actual
# 6122     pulses and nuts  Beans (dry)           262  90 KG    actual
# 6266  cereals and tubers        Maize            51     KG    actual
# 6303  cereals and tubers        Maize            51     KG    actual
# 8751  cereals and tubers        Maize            51     KG    actual
#
#       pricetype currency    price  usdprice
# 6121  Wholesale      KES  4000.00     38.59
# 6122  Wholesale      KES  9200.00     88.76
# 6266  Wholesale      KES    48.02      0.48
# 6303  Wholesale      KES    48.79      0.47
# 8751  Wholesale      KES    35.59      0.31

# %%
market_counts = df['market'].value_counts()
market_counts
# Out:
# market
# Nairobi                       1762
# Eldoret town (Uasin Gishu)    1392
# Kisumu                         962
# IFO (Daadab)                   812
# Kakuma 3                       790
#                               ...
# Vanga (Kwale)                    6
# Adele Center                     6
# Simale                           6
# Lokipoto                         6
# Hara (Garissa)                   5
# Name: count, Length: 226, dtype: int64

# %%
#Horizontal bar chart to visualize the number of observations in the Nairobi, Eldoret, Kisumu and Mombasa
market_counts[['Nairobi', 'Eldoret town (Uasin Gishu)', 'Kisumu', 'Mombasa']].plot(kind='barh')
plt.xlabel('Number of Observations')
plt.ylabel('Market')
plt.title('Number of Observations in Selected Markets')
plt.show()

# %% [markdown]
# <h3>7. Commodity Coverage</h3>

# %%
commodity_counts = df['commodity'].value_counts()
commodity_counts
# Out:
# commodity
# Beans (dry)                   1809
# Maize (white)                 1785
# Maize                         1513
# Sugar                         1412
# Wheat flour                   1411
# Beans                         1382
# Salt                          1327
# Potatoes (Irish)              1324
# Sorghum                       1098
# Rice (aromatic)                992
# Maize (white, dry)             978
# Oil (vegetable)                929
# Milk (cow, pasteurized)        808
# Kale                           785
# Rice                           752
# Maize flour                    749
# Oil (vegetable, fortified)     749
# Maize flour (white)            693
# Bananas                        591
# Milk (UHT)                     563
# Tomatoes                       519
# Cabbage                        485
# Onions (dry)                   471
# Potatoes (Irish, white)        401
# Meat (goat)                    400
# Beans (yellow)                 382
# Meat (beef)                    352
# Spinach                        319
# Cowpeas (dry)                  292
# Meat (camel)                   290
# Beans (rosecoco)               269
# Cowpeas                        255
# Beans (dolichos)               189
# Bread                          178
# Potatoes (Irish, red)          162
# Milk (camel, fresh)            146
# Cooking fat                    124
# Sorghum (white)                122
# Pigeon peas (dry)              111
# Beans (kidney)                 107
# Sorghum (red)                   82
# Millet (finger)                 77
# Fuel (diesel)                   67
# Fuel (petrol-gasoline)          67
# Fuel (kerosene)                 67
# Beans (mung)                    56
# Milk (cow, fresh)               49
# Cowpea leaves                   40
# Fish (omena, dry)               24
# Rice (imported, Pakistan)       20
# Onions (red)                     1
# Name: count, dtype: int64

# %%
#Visualizing the number of observations for Kale, Onions (dry), Tomatoes
commodity_counts[['Kale', 'Onions (dry)', 'Tomatoes']].plot(kind='barh')
plt.xlabel('Number of Observations')
plt.ylabel('Commodity')
plt.title('Number of Observations for Selected Commodities')
plt.show()

# %% [markdown]
# <h3>8. Crop x Market Coverage</h3>

# %%
# Create a market crop matrix for Tomatoes, Onions (dry), Kale with Nairobi, Mombasa, Kisumu, Eldoret (Uasin Gishu)
market_crop_matrix = df.pivot_table(index='market', columns='commodity', aggfunc='size', fill_value=0)
market_crop_matrix = market_crop_matrix.loc[['Nairobi', 'Mombasa', 'Kisumu', 'Eldoret town (Uasin Gishu)'], ['Tomatoes', 'Onions (dry)', 'Kale']]
market_crop_matrix
# Out:
# commodity                   Tomatoes  Onions (dry)  Kale
# market
# Nairobi                            1             0     1
# Mombasa                            0             0     0
# Kisumu                             0             0     0
# Eldoret town (Uasin Gishu)        41            42    39

# %%
# Rank market-crop combinations by observation count to find the best candidates for model training
market_crop_counts = (
    market_crop_matrix
    .stack()
    .rename("observations")
    .reset_index()
    .sort_values("observations", ascending=False)
    .reset_index(drop=True)
)
market_crop_counts
# Out:
#                         market     commodity  observations
# 0   Eldoret town (Uasin Gishu)  Onions (dry)            42
# 1   Eldoret town (Uasin Gishu)      Tomatoes            41
# 2   Eldoret town (Uasin Gishu)          Kale            39
# 3                      Nairobi      Tomatoes             1
# 4                      Nairobi          Kale             1
# 5                      Nairobi  Onions (dry)             0
# 6                      Mombasa      Tomatoes             0
# 7                      Mombasa  Onions (dry)             0
# 8                       Kisumu  Onions (dry)             0
# 9                       Kisumu      Tomatoes             0
# 10                     Mombasa          Kale             0
# 11                      Kisumu          Kale             0

# %%
#Visualizing the number of observations for Maize (white), Maize (white, dry), Maize, Beans (dry), Beans
commodity_counts[['Maize (white)', 'Maize (white, dry)','Maize', 'Beans (dry)','Beans']].plot(kind='barh')
plt.xlabel('Number of Observations')
plt.ylabel('Commodity')
plt.title('Number of Observations for Selected Commodities')
plt.show()

# %%
# Create a market crop matrix for Maize (white), Beans with Nairobi, Mombasa, Kisumu, Eldoret (Uasin Gishu)
market_crop_matrix_2 = df.pivot_table(index='market', columns='commodity', aggfunc='size', fill_value=0)
market_crop_matrix_2 = market_crop_matrix_2.loc[['Nairobi', 'Mombasa', 'Kisumu', 'Eldoret town (Uasin Gishu)'], ['Maize (white)', 'Maize (white, dry)','Maize', 'Beans (dry)','Beans']]
market_crop_matrix_2
# Out:
# commodity                   Maize (white)  Maize (white, dry)  Maize  \
# market
# Nairobi                               170                   0    190
# Mombasa                               167                   0    133
# Kisumu                                164                   0    161
# Eldoret town (Uasin Gishu)            170                  42    188
#
# commodity                   Beans (dry)  Beans
# market
# Nairobi                             171    144
# Mombasa                             167    143
# Kisumu                              155    160
# Eldoret town (Uasin Gishu)          142    156

# %% [markdown]
# <h3>9. Price distribution </h3>

# %%
df['price'].describe()
# Out:
# count    27774.000000
# mean      1287.894294
# std       2541.156010
# min          5.000000
# 25%         70.000000
# 50%        130.000000
# 75%        999.275000
# max      19800.000000
# Name: price, dtype: float64

# %% [markdown]
# <h3>10. Price distribution by Crop</h3>

# %%
# Boxplot of price by crop for Maize
sns.boxplot(x='commodity', y='price', data=df[df['commodity'] == 'Maize'])
plt.title('Price Distribution for Maize')
plt.xlabel('Crop')
plt.ylabel('Price')
plt.show()

# %%
# Boxplot of price by crop for Beans
sns.boxplot(x='commodity', y='price', data=df[df['commodity'] == 'Beans'])
plt.title('Price Distribution for Beans')
plt.xlabel('Crop')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h3>11. Price distribution by Market</h3>

# %%
# Boxplot of price by crop for Maize in Nairobi
sns.boxplot(x='commodity', y='price', data=df[(df['commodity'] == 'Maize') & (df['market'] == 'Nairobi')])
plt.title('Price Distribution for Maize in Nairobi')
plt.xlabel('Crop')
plt.ylabel('Price')
plt.show()

# %%
# Boxplot of price by crop for Maize in Kisumu
sns.boxplot(x='commodity', y='price', data=df[(df['commodity'] == 'Maize') & (df['market'] == 'Kisumu')])
plt.title('Price Distribution for Maize in Kisumu')
plt.xlabel('Crop')
plt.ylabel('Price')
plt.show()

# %%
# Boxplot of price by crop for Maize in Mombasa
sns.boxplot(x='commodity', y='price', data=df[(df['commodity'] == 'Maize') & (df['market'] == 'Mombasa')])
plt.title('Price Distribution for Maize in Mombasa')
plt.xlabel('Crop')
plt.ylabel('Price')
plt.show()

# %%
# Boxplot of price by crop for Maize in Eldoret (Uasin Gishu)
sns.boxplot(x='commodity', y='price', data=df[(df['commodity'] == 'Maize') & (df['market'] == 'Eldoret town (Uasin Gishu)')])
plt.title('Price Distribution for Maize in Eldoret')
plt.xlabel('Crop')
plt.ylabel('Price')
plt.show()

# %%
# Boxplot of price by crop for Beans in Nairobi
sns.boxplot(x='commodity', y='price', data=df[(df['commodity'] == 'Beans') & (df['market'] == 'Nairobi')])
plt.title('Price Distribution for Beans in Nairobi')
plt.xlabel('Crop')
plt.ylabel('Price')
plt.show()

# %%
# Boxplot of price by crop for Beans in Kisumu
sns.boxplot(x='commodity', y='price', data=df[(df['commodity'] == 'Beans') & (df['market'] == 'Kisumu')])
plt.title('Price Distribution for Beans in Kisumu')
plt.xlabel('Crop')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h3>12. Time-series Analysis</h3>

# %%
monthly = (
    df.groupby([
        pd.Grouper(key="date", freq="MS"),
        "market",
        "commodity"
    ])["price"]
    .mean()
    .reset_index()
)

# %%
# Visualization to view monthly price trend for Maize in Nairobi, Mombasa, Eldoret town (Uasin Gishu), Kisumu between 2014 and 2026

markets_of_interest = ["Nairobi", "Mombasa", "Eldoret town (Uasin Gishu)", "Kisumu"]

maize_monthly = monthly[(monthly["commodity"] == "Maize") & (monthly["date"].dt.year >= 2014) & (monthly["date"].dt.year <= 2026)]
for market in markets_of_interest:
    market_data = maize_monthly[maize_monthly["market"] == market]
    plt.plot(market_data["date"], market_data["price"], label=market)
plt.xlabel("Date")
plt.ylabel("Market Price")
plt.title("Monthly Price Trend for Maize")
plt.legend()
plt.show()

# %%
# Visualization to view monthly price trend for Beans in Nairobi, Mombasa, Eldoret town (Uasin Gishu), Kisumu between 2014 and 2026

markets_of_interest = ["Nairobi", "Mombasa", "Eldoret town (Uasin Gishu)", "Kisumu"]

beans_monthly = monthly[(monthly["commodity"] == "Beans") & (monthly["date"].dt.year >= 2014) & (monthly["date"].dt.year <= 2026)]
for market in markets_of_interest:
    market_data = beans_monthly[beans_monthly["market"] == market]
    plt.plot(market_data["date"], market_data["price"], label=market)
plt.xlabel("Date")
plt.ylabel("Market Price")
plt.title("Monthly Price Trend for Beans")
plt.legend()
plt.show()

# %% [markdown]
# <h3>13. Seasonal Analysis</h3>

# %%
# Visualization to view seasonal price profile by month for Maize
monthly["month"] = monthly["date"].dt.month
maize_seasonal = monthly[monthly["commodity"] == "Maize"]
seasonal_profile = maize_seasonal.groupby("month")["price"].mean()
plt.plot(seasonal_profile.index, seasonal_profile.values)
plt.xticks(ticks=range(1, 13), labels=["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])
plt.xlabel("Month")
plt.ylabel("Average Market Price")
plt.title("Average Market Price for Maize per Month")
plt.show()

# %%
# Visualization to view seasonal price profile by month for Beans
monthly["month"] = monthly["date"].dt.month
beans_seasonal = monthly[monthly["commodity"] == "Beans"]
seasonal_profile = beans_seasonal.groupby("month")["price"].mean()
plt.plot(seasonal_profile.index, seasonal_profile.values)
plt.xticks(ticks=range(1, 13), labels=["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])
plt.xlabel("Month")
plt.ylabel("Average Market Price")
plt.title("Average Market Price for Beans per Month")
plt.show()

# %% [markdown]
# <h3>14. Year-over-year Comparison</h3>

# %%
# Visualization to compare average January prices across different years for Maize
january_maize = monthly[(monthly["commodity"] == "Maize") & (monthly["date"].dt.month == 1) & (monthly["date"].dt.year >= 2021) & (monthly["date"].dt.year <= 2026)]
average_january_maize = january_maize.groupby(january_maize["date"].dt.year)["price"].mean()
plt.plot(average_january_maize.index, average_january_maize.values, label="January")
plt.xlabel("Year")
plt.ylabel("Average Market Price")
plt.title("Average January Prices for Maize Across Different Years")
plt.legend()
plt.show()

# %%
# Visualization to compare average January prices across different years for Beans
january_beans = monthly[(monthly["commodity"] == "Beans (dry)") & (monthly["date"].dt.month == 1) & (monthly["date"].dt.year >= 2021) & (monthly["date"].dt.year <= 2026)]
average_january_beans = january_beans.groupby(january_beans["date"].dt.year)["price"].mean()
plt.plot(average_january_beans.index, average_january_beans.values, label="January")
plt.xlabel("Year")
plt.ylabel("Average Market Price")
plt.title("Average January Prices for Beans Across Different Years")
plt.legend()
plt.show()

# %% [markdown]
# <h3>15. Outlier Analysis</h3>

# %%
# Function to identify outlier prices for a given commodity using IQR. The column for date is "date", and i want from 2014 to 2026
def get_outliers(df, commodity):
    df_filtered = df[(df["commodity"] == commodity) & (df["date"].dt.year >= 2014) & (df["date"].dt.year <= 2026)]
    Q1 = df_filtered["price"].quantile(0.25)
    Q3 = df_filtered["price"].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df_filtered[(df_filtered["price"] < lower) | (df_filtered["price"] > upper)]
    return outliers

# %%
# Display outlier prices for Maize from 2014 to 2026 and visualize them
outliers_maize = get_outliers(df, "Maize")
outliers_maize
# Out:
#             date         admin1   admin2              market  market_id  \
# 23195 2023-05-15    Rift Valley  Turkana   Ethiopia (Kakuma)       3253
# 23581 2023-08-15  North Eastern  Garissa  Dagahaley (Daadab)       3252
# 23742 2023-09-15    Rift Valley  Turkana   Ethiopia (Kakuma)       3253
# 23753 2023-09-15    Rift Valley  Turkana   HongKong (Kakuma)       3250
# 24211 2024-01-15  North Eastern  Garissa  Dagahaley (Daadab)       3252
# 24485 2024-03-15    Rift Valley  Turkana   HongKong (Kakuma)       3250
#
#        latitude  longitude            category commodity  commodity_id unit  \
# 23195      3.72      34.85  cereals and tubers     Maize            51   KG
# 23581      0.19      40.29  cereals and tubers     Maize            51   KG
# 23742      3.72      34.85  cereals and tubers     Maize            51   KG
# 23753      3.75      34.84  cereals and tubers     Maize            51   KG
# 24211      0.19      40.29  cereals and tubers     Maize            51   KG
# 24485      3.75      34.84  cereals and tubers     Maize            51   KG
#
#        priceflag pricetype currency  price  usdprice
# 23195  aggregate    Retail      KES  100.0      0.73
# 23581  aggregate    Retail      KES  120.0      0.83
# 23742  aggregate    Retail      KES  100.0      0.68
# 23753  aggregate    Retail      KES  100.0      0.68
# 24211  aggregate    Retail      KES  100.0      0.63
# 24485  aggregate    Retail      KES  100.0      0.75

# %%
plt.figure(figsize=(10, 6))
plt.scatter(outliers_maize["date"], outliers_maize["price"], color='red', label='Outliers')
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.ylabel("Price")
plt.title("Outlier Maize Prices from 2014 to 2026")
plt.legend()
plt.show()

# %%
# Display outlier prices for beans
outliers_beans = get_outliers(df, "Beans")
outliers_beans
# Out:
# Empty DataFrame
# Columns: [date, admin1, admin2, market, market_id, latitude, longitude, category, commodity, commodity_id, unit, priceflag, pricetype, currency, price, usdprice]
# Index: []
